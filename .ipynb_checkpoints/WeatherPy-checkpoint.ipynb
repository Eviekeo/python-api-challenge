# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=" + units + "&q=" + city
    #f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | den burg
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | qapqal
# City not found. Skipping...
# Processing Record 9 of Set 1 | srivardhan
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | santana
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | malpica
# Processing Record 14 of Set 1 | clarksdale
# Processing Record 15 of Set 1 | the bottom
# Processing Record 16 of Set 1 | viqueque
# Processing Record 17 of Set 1 | colchani
# Processing Record 18 of Set 1 | darnah
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | beboto
# Processing Record 22 of Set 1 | olonkinbyen
# Processing Record 23 of Set 1 | cherdyn'
# Processing Record 24 of Set 1 | tolanaro
# Processing Record 25 of Set 1 | chonchi
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | west island
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | antofagasta
# Processing Record 31 of Set 1 | wailua homesteads
# Processing Record 32 of Set 1 | kayangel
# Processing Record 33 of Set 1 | weno
# Processing Record 34 of Set 1 | waitangi
# Processing Record 35 of Set 1 | belyy yar
# Processing Record 36 of Set 1 | afaahiti
# Processing Record 37 of Set 1 | invercargill
# Processing Record 38 of Set 1 | bilibino
# Processing Record 39 of Set 1 | tamanrasset
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | fort-shevchenko
# Processing Record 42 of Set 1 | uturoa
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | klyuchi
# Processing Record 45 of Set 1 | selfoss
# Processing Record 46 of Set 1 | labrador city
# Processing Record 47 of Set 1 | remire-montjoly
# Processing Record 48 of Set 1 | praia
# Processing Record 49 of Set 1 | sarupathar
# Processing Record 50 of Set 1 | pula
# Processing Record 0 of Set 2 | harstad
# Processing Record 1 of Set 2 | papatowai
# Processing Record 2 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 2 | colonia menno
# Processing Record 4 of Set 2 | ilhabela
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | morigaon
# Processing Record 7 of Set 2 | medina
# Processing Record 8 of Set 2 | qaqortoq
# Processing Record 9 of Set 2 | carbonear
# Processing Record 10 of Set 2 | suong
# City not found. Skipping...
# Processing Record 11 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | cotoca
# Processing Record 15 of Set 2 | puerto santa
# Processing Record 16 of Set 2 | tanjung pandan
# Processing Record 17 of Set 2 | fisterra
# Processing Record 18 of Set 2 | brookings
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | verkhnevilyuysk
# Processing Record 21 of Set 2 | ndjole
# Processing Record 22 of Set 2 | galdar
# Processing Record 23 of Set 2 | san patricio
# Processing Record 24 of Set 2 | kerema
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | alesund
# Processing Record 28 of Set 2 | nangong
# Processing Record 29 of Set 2 | burabay
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | ramhormoz
# Processing Record 32 of Set 2 | eyl
# Processing Record 33 of Set 2 | taoudenni
# Processing Record 34 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 35 of Set 2 | saipan
# Processing Record 36 of Set 2 | nova sintra
# Processing Record 37 of Set 2 | colonia
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | khorixas
# Processing Record 40 of Set 2 | bokoro
# Processing Record 41 of Set 2 | dunedin
# Processing Record 42 of Set 2 | margaret river
# Processing Record 43 of Set 2 | stanley
# Processing Record 44 of Set 2 | ostersund
# Processing Record 45 of Set 2 | buala
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | tukrah
# Processing Record 48 of Set 2 | beyneu
# Processing Record 49 of Set 2 | cam ranh
# Processing Record 0 of Set 3 | mount pearl
# Processing Record 1 of Set 3 | kanel
# Processing Record 2 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 3 of Set 3 | nuuk
# Processing Record 4 of Set 3 | vorgashor
# Processing Record 5 of Set 3 | rongelap
# Processing Record 6 of Set 3 | coquimbo
# Processing Record 7 of Set 3 | greymouth
# Processing Record 8 of Set 3 | fale old settlement
# Processing Record 9 of Set 3 | kultali
# City not found. Skipping...
# Processing Record 10 of Set 3 | inongo
# Processing Record 11 of Set 3 | es castell
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | san antonio de pale
# Processing Record 14 of Set 3 | ipameri
# Processing Record 15 of Set 3 | cestos city
# Processing Record 16 of Set 3 | mejit
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | kapa'a
# Processing Record 19 of Set 3 | vadso
# Processing Record 20 of Set 3 | berezovyy
# Processing Record 21 of Set 3 | atafu village
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | as sulayyil
# Processing Record 24 of Set 3 | aroma
# Processing Record 25 of Set 3 | iskateley
# Processing Record 26 of Set 3 | rio grande
# Processing Record 27 of Set 3 | tralee
# Processing Record 28 of Set 3 | crane
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | gornopravdinsk
# Processing Record 31 of Set 3 | la'ie
# Processing Record 32 of Set 3 | burutu
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | badger
# Processing Record 35 of Set 3 | isafjordur
# Processing Record 36 of Set 3 | sassandra
# Processing Record 37 of Set 3 | kokkola
# Processing Record 38 of Set 3 | fort st. john
# Processing Record 39 of Set 3 | golfito
# Processing Record 40 of Set 3 | sweetwater
# Processing Record 41 of Set 3 | aktau
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | lata
# Processing Record 44 of Set 3 | saint-francois
# Processing Record 45 of Set 3 | utrik
# Processing Record 46 of Set 3 | port blair
# Processing Record 47 of Set 3 | hawaiian paradise park
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 0 of Set 4 | port mathurin
# Processing Record 1 of Set 4 | aasiaat
# Processing Record 2 of Set 4 | lago da pedra
# Processing Record 3 of Set 4 | tofol
# Processing Record 4 of Set 4 | kambove
# Processing Record 5 of Set 4 | korla
# Processing Record 6 of Set 4 | azul
# Processing Record 7 of Set 4 | el bayadh
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | sungai raya
# Processing Record 12 of Set 4 | quellon
# Processing Record 13 of Set 4 | iquique
# Processing Record 14 of Set 4 | tsiombe
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | ondjiva
# Processing Record 17 of Set 4 | lihue
# Processing Record 18 of Set 4 | ulsteinvik
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | newman
# Processing Record 21 of Set 4 | marquette
# Processing Record 22 of Set 4 | mazamari
# Processing Record 23 of Set 4 | howrah
# Processing Record 24 of Set 4 | la passe
# Processing Record 25 of Set 4 | elk city
# Processing Record 26 of Set 4 | karkira
# Processing Record 27 of Set 4 | maumere
# Processing Record 28 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 29 of Set 4 | tateyama
# Processing Record 30 of Set 4 | vrangel'
# Processing Record 31 of Set 4 | anadyr
# Processing Record 32 of Set 4 | khorugh
# Processing Record 33 of Set 4 | ebon
# Processing Record 34 of Set 4 | seminole
# Processing Record 35 of Set 4 | oranjemund
# Processing Record 36 of Set 4 | derzhavinsk
# Processing Record 37 of Set 4 | valparaiso
# Processing Record 38 of Set 4 | fort bragg
# Processing Record 39 of Set 4 | manacapuru
# Processing Record 40 of Set 4 | tazovsky
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | oodweyne
# Processing Record 43 of Set 4 | vershino-darasunskiy
# Processing Record 44 of Set 4 | catriel
# Processing Record 45 of Set 4 | polyarnyy
# Processing Record 46 of Set 4 | bushland beach
# City not found. Skipping...
# Processing Record 47 of Set 4 | port arthur
# Processing Record 48 of Set 4 | howard springs
# Processing Record 49 of Set 4 | udachny
# Processing Record 0 of Set 5 | kodinsk
# Processing Record 1 of Set 5 | hammerfest
# Processing Record 2 of Set 5 | yung shue wan
# Processing Record 3 of Set 5 | oamaru
# Processing Record 4 of Set 5 | mabaruma
# Processing Record 5 of Set 5 | bani mazar
# Processing Record 6 of Set 5 | vilyuchinsk
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | luderitz
# Processing Record 9 of Set 5 | niquelandia
# Processing Record 10 of Set 5 | mazar-e sharif
# Processing Record 11 of Set 5 | emerald
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | mhamid
# Processing Record 14 of Set 5 | pontes e lacerda
# Processing Record 15 of Set 5 | namibe
# Processing Record 16 of Set 5 | kristiansund
# Processing Record 17 of Set 5 | antsiranana
# Processing Record 18 of Set 5 | constantia
# Processing Record 19 of Set 5 | karratha
# Processing Record 20 of Set 5 | baruun-urt
# Processing Record 21 of Set 5 | sampit
# Processing Record 22 of Set 5 | kone
# Processing Record 23 of Set 5 | kokpekty
# Processing Record 24 of Set 5 | bamboo flat
# Processing Record 25 of Set 5 | pudozh
# Processing Record 26 of Set 5 | tonala
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | gizo
# Processing Record 29 of Set 5 | al muwayh
# Processing Record 30 of Set 5 | hasaki
# Processing Record 31 of Set 5 | kailua-kona
# Processing Record 32 of Set 5 | pagar alam
# Processing Record 33 of Set 5 | zeralda
# Processing Record 34 of Set 5 | rundu
# Processing Record 35 of Set 5 | correntina
# Processing Record 36 of Set 5 | port macquarie
# Processing Record 37 of Set 5 | dobrinka
# Processing Record 38 of Set 5 | byron bay
# Processing Record 39 of Set 5 | mong cai
# City not found. Skipping...
# Processing Record 40 of Set 5 | janauba
# Processing Record 41 of Set 5 | inderbor
# Processing Record 42 of Set 5 | znamenskoye
# Processing Record 43 of Set 5 | chambas
# Processing Record 44 of Set 5 | butia
# Processing Record 45 of Set 5 | basco
# Processing Record 46 of Set 5 | lompoc
# Processing Record 47 of Set 5 | kavieng
# Processing Record 48 of Set 5 | soio
# Processing Record 49 of Set 5 | mana
# Processing Record 0 of Set 6 | scottburgh
# Processing Record 1 of Set 6 | bulakamba
# Processing Record 2 of Set 6 | paracuru
# Processing Record 3 of Set 6 | dehri
# Processing Record 4 of Set 6 | selkirk
# Processing Record 5 of Set 6 | torquay
# Processing Record 6 of Set 6 | minas de marcona
# Processing Record 7 of Set 6 | yamba
# Processing Record 8 of Set 6 | richards bay
# Processing Record 9 of Set 6 | roma
# Processing Record 10 of Set 6 | puerto aysen
# Processing Record 11 of Set 6 | ribeira brava
# Processing Record 12 of Set 6 | vernon
# Processing Record 13 of Set 6 | pechora
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | tezu
# Processing Record 16 of Set 6 | rabaul
# Processing Record 17 of Set 6 | dudinka
# Processing Record 18 of Set 6 | troitsko-pechorsk
# Processing Record 19 of Set 6 | sosnogorsk
# Processing Record 20 of Set 6 | luchegorsk
# Processing Record 21 of Set 6 | ulladulla
# Processing Record 22 of Set 6 | baringo
# Processing Record 23 of Set 6 | sa'dah
# Processing Record 24 of Set 6 | serang
# Processing Record 25 of Set 6 | mo i rana
# Processing Record 26 of Set 6 | nemuro
# Processing Record 27 of Set 6 | mbanza kongo
# Processing Record 28 of Set 6 | ta`u
# Processing Record 29 of Set 6 | whistler
# Processing Record 30 of Set 6 | nar'yan-mar
# Processing Record 31 of Set 6 | tame
# Processing Record 32 of Set 6 | bani walid
# Processing Record 33 of Set 6 | mutum
# Processing Record 34 of Set 6 | lebu
# Processing Record 35 of Set 6 | bardai
# Processing Record 36 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 37 of Set 6 | springbok
# Processing Record 38 of Set 6 | north battleford
# Processing Record 39 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 6 | kill devil hills
# Processing Record 41 of Set 6 | tazacorte
# Processing Record 42 of Set 6 | papao
# Processing Record 43 of Set 6 | luang prabang
# Processing Record 44 of Set 6 | san juan
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | severo-yeniseyskiy
# Processing Record 49 of Set 6 | lagos
# Processing Record 0 of Set 7 | ocean shores
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | sinabang
# Processing Record 3 of Set 7 | dolores
# Processing Record 4 of Set 7 | puerto deseado
# Processing Record 5 of Set 7 | guiuan
# Processing Record 6 of Set 7 | golere
# Processing Record 7 of Set 7 | city of isabela
# Processing Record 8 of Set 7 | pelhrimov
# Processing Record 9 of Set 7 | tanda
# Processing Record 10 of Set 7 | la mana
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | chirilagua
# Processing Record 13 of Set 7 | panguipulli
# Processing Record 14 of Set 7 | cananeia
# Processing Record 15 of Set 7 | mammoth lakes
# Processing Record 16 of Set 7 | salinopolis
# Processing Record 17 of Set 7 | greenville
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | vallenar
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | altamira
# Processing Record 22 of Set 7 | akureyri
# Processing Record 23 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 7 | daye
# Processing Record 25 of Set 7 | persembe
# Processing Record 26 of Set 7 | sirsa
# Processing Record 27 of Set 7 | xilin hot
# Processing Record 28 of Set 7 | kargil
# Processing Record 29 of Set 7 | mili
# Processing Record 30 of Set 7 | cannonvale
# Processing Record 31 of Set 7 | labytnangi
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | kulhudhuffushi
# Processing Record 34 of Set 7 | terrace
# Processing Record 35 of Set 7 | el calafate
# Processing Record 36 of Set 7 | san julian
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | duong dong
# Processing Record 40 of Set 7 | bima
# Processing Record 41 of Set 7 | ola
# Processing Record 42 of Set 7 | cholpon-ata
# Processing Record 43 of Set 7 | boa vista
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 46 of Set 7 | san borja
# Processing Record 47 of Set 7 | masterton
# Processing Record 48 of Set 7 | okoneshnikovo
# Processing Record 49 of Set 7 | novyy urengoy
# Processing Record 0 of Set 8 | ceeldheer
# Processing Record 1 of Set 8 | monchegorsk
# Processing Record 2 of Set 8 | suva
# Processing Record 3 of Set 8 | sirte
# Processing Record 4 of Set 8 | lamu
# Processing Record 5 of Set 8 | ravar
# Processing Record 6 of Set 8 | ad dawadimi
# Processing Record 7 of Set 8 | port saint john's
# Processing Record 8 of Set 8 | usinsk
# Processing Record 9 of Set 8 | brisas de zicatela
# Processing Record 10 of Set 8 | chui
# Processing Record 11 of Set 8 | tidjikja
# Processing Record 12 of Set 8 | fort mcmurray
# Processing Record 13 of Set 8 | costa teguise
# City not found. Skipping...
# Processing Record 14 of Set 8 | east end
# Processing Record 15 of Set 8 | sabha
# Processing Record 16 of Set 8 | bagasra
# Processing Record 17 of Set 8 | east london
# Processing Record 18 of Set 8 | puerto cabezas
# Processing Record 19 of Set 8 | lazaro cardenas
# Processing Record 20 of Set 8 | walvis bay
# Processing Record 21 of Set 8 | dryden
# Processing Record 22 of Set 8 | burang
# Processing Record 23 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 24 of Set 8 | saint-joseph
# Processing Record 25 of Set 8 | yanchep
# Processing Record 26 of Set 8 | haiku-pauwela
# Processing Record 27 of Set 8 | holualoa
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | sandnessjoen
# Processing Record 30 of Set 8 | college
# Processing Record 31 of Set 8 | santo domingo de los colorados
# Processing Record 32 of Set 8 | acapetahua
# Processing Record 33 of Set 8 | cadale
# Processing Record 34 of Set 8 | plouzane
# Processing Record 35 of Set 8 | laayoune plage
# City not found. Skipping...
# Processing Record 36 of Set 8 | mhasvad
# Processing Record 37 of Set 8 | huangnihe
# Processing Record 38 of Set 8 | antalaha
# Processing Record 39 of Set 8 | semey
# Processing Record 40 of Set 8 | nurota
# Processing Record 41 of Set 8 | port-vila
# Processing Record 42 of Set 8 | raton
# Processing Record 43 of Set 8 | keflavik
# Processing Record 44 of Set 8 | stephenville
# Processing Record 45 of Set 8 | saint-pierre
# Processing Record 46 of Set 8 | mossel bay
# Processing Record 47 of Set 8 | mollendo
# Processing Record 48 of Set 8 | villas de irapuato
# City not found. Skipping...
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 0 of Set 9 | shevchenko
# Processing Record 1 of Set 9 | accra
# Processing Record 2 of Set 9 | ixtapa
# Processing Record 3 of Set 9 | kuybyshev
# Processing Record 4 of Set 9 | abanilla
# Processing Record 5 of Set 9 | moyo
# Processing Record 6 of Set 9 | yarkovo
# Processing Record 7 of Set 9 | barra de santo antonio
# Processing Record 8 of Set 9 | viedma
# Processing Record 9 of Set 9 | macon
# Processing Record 10 of Set 9 | chegdomyn
# Processing Record 11 of Set 9 | kitimat
# Processing Record 12 of Set 9 | sayat
# Processing Record 13 of Set 9 | debark'
# Processing Record 14 of Set 9 | panambi
# Processing Record 15 of Set 9 | hibbing
# Processing Record 16 of Set 9 | juan griego
# Processing Record 17 of Set 9 | gudauri
# City not found. Skipping...
# Processing Record 18 of Set 9 | nagqu
# Processing Record 19 of Set 9 | jinchang
# Processing Record 20 of Set 9 | port-gentil
# Processing Record 21 of Set 9 | auki
# Processing Record 22 of Set 9 | saquarema
# Processing Record 23 of Set 9 | funafuti
# Processing Record 24 of Set 9 | muncar
# Processing Record 25 of Set 9 | conception bay south
# Processing Record 26 of Set 9 | englewood
# Processing Record 27 of Set 9 | happy valley-goose bay
# Processing Record 28 of Set 9 | middelburg
# Processing Record 29 of Set 9 | sur
# Processing Record 30 of Set 9 | san lawrenz
# Processing Record 31 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 32 of Set 9 | santa rosa
# Processing Record 33 of Set 9 | zarghun shahr
# Processing Record 34 of Set 9 | sao francisco
# Processing Record 35 of Set 9 | verkhniy baskunchak
# Processing Record 36 of Set 9 | yuzhno-kurilsk
# Processing Record 37 of Set 9 | bengkulu
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | lorengau
# Processing Record 40 of Set 9 | muriae
# Processing Record 41 of Set 9 | dazhou
# Processing Record 42 of Set 9 | gaalkacyo
# Processing Record 43 of Set 9 | vozhega
# Processing Record 44 of Set 9 | moyynkum
# Processing Record 45 of Set 9 | bam
# Processing Record 46 of Set 9 | dickinson
# Processing Record 47 of Set 9 | sejenane
# Processing Record 48 of Set 9 | cole harbour
# Processing Record 49 of Set 9 | igarka
# Processing Record 0 of Set 10 | pahrump
# Processing Record 1 of Set 10 | olyokminsk
# Processing Record 2 of Set 10 | riberalta
# Processing Record 3 of Set 10 | sao gabriel da cachoeira
# Processing Record 4 of Set 10 | paradsasvar
# Processing Record 5 of Set 10 | madimba
# Processing Record 6 of Set 10 | gamboma
# Processing Record 7 of Set 10 | bundibugyo
# Processing Record 8 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 10 | haifa
# Processing Record 10 of Set 10 | charlottetown
# Processing Record 11 of Set 10 | horta
# Processing Record 12 of Set 10 | st. john's
# Processing Record 13 of Set 10 | barcelos
# Processing Record 14 of Set 10 | al ghayzah
# Processing Record 15 of Set 10 | thunder bay
# Processing Record 16 of Set 10 | isabela
# Processing Record 17 of Set 10 | mil'kovo
# Processing Record 18 of Set 10 | nieuw amsterdam
# Processing Record 19 of Set 10 | mournies
# Processing Record 20 of Set 10 | norderney
# Processing Record 21 of Set 10 | kugesi
# Processing Record 22 of Set 10 | ust-nera
# Processing Record 23 of Set 10 | susuman
# Processing Record 24 of Set 10 | umba
# Processing Record 25 of Set 10 | roleystone
# Processing Record 26 of Set 10 | tinajo
# Processing Record 27 of Set 10 | dolinsk
# Processing Record 28 of Set 10 | dubbo
# Processing Record 29 of Set 10 | bangjun
# Processing Record 30 of Set 10 | egilsstadir
# Processing Record 31 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 10 | jackson
# Processing Record 33 of Set 10 | jiazi
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | amga
# Processing Record 36 of Set 10 | manokwari
# Processing Record 37 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 38 of Set 10 | ust'-kut
# Processing Record 39 of Set 10 | buka
# Processing Record 40 of Set 10 | castillos
# Processing Record 41 of Set 10 | sassenberg
# Processing Record 42 of Set 10 | saint-philippe
# Processing Record 43 of Set 10 | kolondieba
# Processing Record 44 of Set 10 | coracora
# Processing Record 45 of Set 10 | yaren
# Processing Record 46 of Set 10 | mizdah
# Processing Record 47 of Set 10 | alta
# Processing Record 48 of Set 10 | tocopilla
# Processing Record 49 of Set 10 | singkil
# Processing Record 0 of Set 11 | kudahuvadhoo
# Processing Record 1 of Set 11 | dakhla
# Processing Record 2 of Set 11 | arthur's town
# City not found. Skipping...
# Processing Record 3 of Set 11 | hansi
# Processing Record 4 of Set 11 | acarau
# Processing Record 5 of Set 11 | boguszow-gorce
# Processing Record 6 of Set 11 | basoko
# Processing Record 7 of Set 11 | anna regina
# Processing Record 8 of Set 11 | dobryanka
# Processing Record 9 of Set 11 | levanger
# Processing Record 10 of Set 11 | kremenets
# Processing Record 11 of Set 11 | onega
# Processing Record 12 of Set 11 | nabire
# Processing Record 13 of Set 11 | asosa
# Processing Record 14 of Set 11 | poso
# Processing Record 15 of Set 11 | yelizovo
# Processing Record 16 of Set 11 | kerbakhiar
# Processing Record 17 of Set 11 | kerikeri
# Processing Record 18 of Set 11 | tianchang
# Processing Record 19 of Set 11 | bandarbeyla
# Processing Record 20 of Set 11 | martapura
# Processing Record 21 of Set 11 | enewetak
# Processing Record 22 of Set 11 | kati
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | morada nova
# Processing Record 25 of Set 11 | vylkove
# Processing Record 26 of Set 11 | hamilton
# Processing Record 27 of Set 11 | paita
# Processing Record 28 of Set 11 | raja
# Processing Record 29 of Set 11 | tuxtepec
# Processing Record 30 of Set 11 | at taj
# Processing Record 31 of Set 11 | kapuskasing
# Processing Record 32 of Set 11 | dogondoutchi
# Processing Record 33 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 11 | clear lake
# Processing Record 35 of Set 11 | bafq
# Processing Record 36 of Set 11 | la gi
# Processing Record 37 of Set 11 | shache
# Processing Record 38 of Set 11 | queenstown
# Processing Record 39 of Set 11 | sefwi wiawso
# City not found. Skipping...
# Processing Record 40 of Set 11 | long beach
# Processing Record 41 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 42 of Set 11 | zakynthos
# Processing Record 43 of Set 11 | bonthe
# Processing Record 44 of Set 11 | penzance
# Processing Record 45 of Set 11 | arkhangel'sk
# Processing Record 46 of Set 11 | saint george
# Processing Record 47 of Set 11 | kuanda
# Processing Record 48 of Set 11 | babayurt
# Processing Record 49 of Set 11 | tual
# Processing Record 0 of Set 12 | el bauga
# Processing Record 1 of Set 12 | callao
# Processing Record 2 of Set 12 | andergrove
# Processing Record 3 of Set 12 | qasr-e qand
# City not found. Skipping...
# Processing Record 4 of Set 12 | daromehar
# Processing Record 5 of Set 12 | waingapu
# Processing Record 6 of Set 12 | uliastay
# Processing Record 7 of Set 12 | hadibu
# Processing Record 8 of Set 12 | darwin
# Processing Record 9 of Set 12 | pasargad
# City not found. Skipping...
# Processing Record 10 of Set 12 | zangguy
# City not found. Skipping...
# Processing Record 11 of Set 12 | hinton
# Processing Record 12 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 12 | tangalle
# Processing Record 14 of Set 12 | obolo-eke (1)
# Processing Record 15 of Set 12 | canyon lake
# Processing Record 16 of Set 12 | roha
# Processing Record 17 of Set 12 | dzhangala
# Processing Record 18 of Set 12 | balqash
# Processing Record 19 of Set 12 | black point
# Processing Record 20 of Set 12 | laghouat
# Processing Record 21 of Set 12 | kutum
# Processing Record 22 of Set 12 | vastaboland
# City not found. Skipping...
# Processing Record 23 of Set 12 | faya-largeau
# Processing Record 24 of Set 12 | inebolu
# Processing Record 25 of Set 12 | sao raimundo nonato
# Processing Record 26 of Set 12 | odemira
# Processing Record 27 of Set 12 | douentza
# Processing Record 28 of Set 12 | prince rupert
# Processing Record 29 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 30 of Set 12 | makhambet
# Processing Record 31 of Set 12 | srandakan
# Processing Record 32 of Set 12 | naliya
# Processing Record 33 of Set 12 | cafayate
# Processing Record 34 of Set 12 | fairless hills
# Processing Record 35 of Set 12 | new norfolk
# Processing Record 36 of Set 12 | charters towers
# Processing Record 37 of Set 12 | blythe
# Processing Record 38 of Set 12 | idaho falls
# Processing Record 39 of Set 12 | moron
# Processing Record 40 of Set 12 | san andres
# Processing Record 41 of Set 12 | axim
# Processing Record 42 of Set 12 | tobol'sk
# Processing Record 43 of Set 12 | black river
# Processing Record 44 of Set 12 | shofirkon shahri
# City not found. Skipping...
# Processing Record 45 of Set 12 | murzuq
# Processing Record 46 of Set 12 | skeldon
# Processing Record 47 of Set 12 | menaka
# Processing Record 48 of Set 12 | waterloo
# Processing Record 49 of Set 12 | churapcha
# Processing Record 0 of Set 13 | tan-tan
# Processing Record 1 of Set 13 | pointe-noire
# Processing Record 2 of Set 13 | chibougamau
# Processing Record 3 of Set 13 | kralendijk
# Processing Record 4 of Set 13 | port douglas
# Processing Record 5 of Set 13 | alghero
# Processing Record 6 of Set 13 | kota belud
# Processing Record 7 of Set 13 | guajara mirim
# Processing Record 8 of Set 13 | cuyo
# Processing Record 9 of Set 13 | cooper's town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           den burg  53.0542    4.7972     17.20        97         100
# 1  port-aux-francais -49.3500   70.2167      5.73        86          99
# 2          adamstown -25.0660 -130.1015     21.25        67           0
# 3      blackmans bay -43.0167  147.3167      9.74        81          70
# 4           la ronge  55.1001 -105.2842     11.14        93           0
#
#    Wind Speed Country        Date
# 0       10.80      NL  1690102877
# 1       16.40      TF  1690102518
# 2        8.66      PN  1690102515
# 3        2.69      AU  1690102515
# 4        0.00      CA  1690102547

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 den burg  53.0542    4.7972     17.20        97         100
# 1        port-aux-francais -49.3500   70.2167      5.73        86          99
# 2                adamstown -25.0660 -130.1015     21.25        67           0
# 3            blackmans bay -43.0167  147.3167      9.74        81          70
# 4                 la ronge  55.1001 -105.2842     11.14        93           0
#
#          Wind Speed Country        Date
# City_ID
# 0             10.80      NL  1690102877
# 1             16.40      TF  1690102518
# 2              8.66      PN  1690102515
# 3              2.69      AU  1690102515
# 4              0.00      CA  1690102547

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", alpha=0.8, edgecolor="black")

#import datetime module
import datetime
today = datetime.date.today()

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (" + str(today) + ")")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", alpha=0.8, edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (" + str(today) + ")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", alpha=0.8, edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (" + str(today) + ")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", alpha=0.8, edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (" + str(today) + ")")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_func(x,y,x_coord,y_coord):
    plt.scatter(x, y, marker="o", alpha=0.8)
    slope, intercept, r, p, se = linregress(x, y)
    # y = mx + b equation
    y_values = slope * x + intercept
    eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    plt.plot(x, y_values, color="red")

    print(f"The r-value is: {r**2}")

    plt.annotate(eq,
                 xy = (x_coord,y_coord),
                 color = "red",
                 fontsize = 13,
                 fontweight = "normal"
                 )

    # Incorporate the other graph properties
    plt.ylabel(y.name)
    plt.xlabel("Latitude")

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[(city_data_df['Lat']>=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          den burg  53.0542    4.7972     17.20        97         100
# 4          la ronge  55.1001 -105.2842     11.14        93           0
# 7        srivardhan  18.0333   73.0167     26.58        89         100
# 10           bethel  41.3712  -73.4140     18.75        86           0
# 11          malpica  43.3228   -8.8105     20.76        80         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.80      NL  1690102877
# 4              0.00      CA  1690102547
# 7              8.40      IN  1690102882
# 10             1.54      US  1690102513
# 11             4.68      ES  1690102884

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[(city_data_df['Lat']<0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                  port-aux-francais -49.3500   70.2167      5.73        86
# 2                          adamstown -25.0660 -130.1015     21.25        67
# 3                      blackmans bay -43.0167  147.3167      9.74        81
# 5        edinburgh of the seven seas -37.0676  -12.3116     13.37        78
# 6                          grytviken -54.2811  -36.5092     -5.36        76
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                99       16.40      TF  1690102518
# 2                 0        8.66      PN  1690102515
# 3                70        2.69      AU  1690102515
# 5                40        9.63      SH  1690102512
# 6                35        4.99      GS  1690102512

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]
linear_func(x,y,50,40)
# Out:
# The r-value is: 0.27922688041309107

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]
linear_func(x,y,-20,0)
# Out:
# The r-value is: 0.7238889158899003

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a medium-strength negative correlation between latitude and maximum temperature on the Northern Hemisphere. This means that typically the farther north from the equator a city is positioned, the lower its maximum temperature will be.
# There is a  medium-strength positive correlation between latitude and maximum temperature on the Southern Hemisphere. This means that typically the closer to the equator a city is positioned, the higher its maximum temperature will be.
#
# There is more variance in the maximum temperature on the Northern Hemisphere than the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]
linear_func(x,y,55,10)
# Out:
# The r-value is: 4.558006273890707e-05

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]
linear_func(x,y,-50,20)
# Out:
# The r-value is: 0.0104736695265375

# %% [markdown]
# **Discussion about the linear relationship:**
# There is almost no correlation or relationship between a city's position from the equator and its humidity level. The relationship is weaker for cities in the Northern Hemisphere than in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Cloudiness"]
linear_func(x,y,60,15)
# Out:
# The r-value is: 0.0010006044876450229

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Cloudiness"]
linear_func(x,y,-50,30)
# Out:
# The r-value is: 0.0011931910528824212

# %% [markdown]
# **Discussion about the linear relationship:**
# There is no correlation or relationship between a city's position from the equator and its cloudiness level. The levels of cloudiness is more dispersed across all latitudes in the Northen Hemisphere than the Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Wind Speed"]
linear_func(x,y,10,15)
# Out:
# The r-value is: 0.03443429733535439

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Wind Speed"]
linear_func(x,y,-50,8)
# Out:
# The r-value is: 0.015938493308030495

# %% [markdown]
# **Discussion about the linear relationship:**
# There is almost no correlation between a city's position from the equator and its wind speed. For most of the latitudes in the Northern and Southern Hemisphere, the wind speed is between 0 m/s to 10 m/s.
